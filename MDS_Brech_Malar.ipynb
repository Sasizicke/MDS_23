# %%
# Import Python packages 
import pandas as pd
#import cassandra
import re
import os
import glob
import numpy as np
import json
import csv

# %%
import os
path = 'D:/Studium/Master/MDS/Daten'
path2 = 'D:/Studium/Master/MDS/Pre_Daten'
path3 = 'D:/Studium/Master/MDS/Pre_Daten/Catching'
path4 = 'D:/Studium/Master/MDS/Pre_Daten/Wardrobe'
path5 = 'D:/Studium/Master/MDS/Pre_Daten/Furniture'
os_ls = os.listdir(path) 
os_ls2 =  os.listdir(path2) 
os_ls_cat =  os.listdir(path3) 
os_ls_ac =  os.listdir(path4) 
os_ls_fur =  os.listdir(path5)

# %%
import os
path = 'D:/Studium/Master/MDS/Daten'
path2 = 'D:/Studium/Master/MDS/Pre_Daten'
path3 = 'D:/Studium/Master/MDS/Pre_Daten/Catching_Cas'
path4 = 'D:/Studium/Master/MDS/Pre_Daten/Wardrobe_Cas'
path5 = 'D:/Studium/Master/MDS/Pre_Daten/Furniture_Cas'
os_ls = os.listdir(path) 
os_ls2 =  os.listdir(path2) 
os_ls_cat =  os.listdir(path3) 
os_ls_ac =  os.listdir(path4) 
os_ls_fur =  os.listdir(path5)

# %%
import csv
import numpy as np
import re
for file in os_ls:
    with open(path + '/'+ file, "r", encoding='utf8') as f:
        with open (path2 + '/'+ file + "", "w", encoding='utf8', newline='') as d:
            csvreader = csv.reader(f)
            csv_writer = csv.writer(d)
            for line in csvreader:
                if line[len(line)-1] == '':
                    continue
                else:
                    line = ["" if x == 'NA' else x for x in line]
                    line = ["" if x == 'NFS' else x for x in line]
                    line = ['True' if x == 'Yes' else x for x in line]
                    line = ['False' if x == 'No' else x for x in line]
                    line = [x.replace(u'\xa0', ' ') for x in line]
                    line = [x.replace('"', '') for x in line]
                    line = [x.replace(',', ';') for x in line]
                    line = [x.replace(u'\ufeff', '') for x in line]
                    line = [line]
                    csv_writer.writerows(line)
                #break

# %%
ls_u_cat = []
for file in os_ls_cat:
    df = pd.read_csv(path3 + '/'+ file)
    ls = (df["Unique Entry ID"].tolist())
    for l in ls:
        ls_u_cat.append(l)

# %%
ls_u_fur = []
for file in os_ls_fur:
    df = pd.read_csv(path5 + '/'+ file)
    ls = (df["Unique Entry ID"].tolist())
    for l in ls:
        ls_u_fur.append(l)

# %%
ls_u_ac = []
for file in os_ls_ac:
    df = pd.read_csv(path4 + '/'+ file)
    ls = (df["Unique Entry ID"].tolist())
    for l in ls:
        ls_u_ac.append(l)

# %%
str1 = ""
str2 = ""
str3 = ""
Counter = 1
for file in os_ls_ac:
    filename = str(file).replace('.csv', '').upper()
    string = ""
    string2 = ""
    
    df = pd.read_csv(path4 + '/'+ file)
    ls_u_ac = (df["Unique Entry ID"].tolist())
    for x in ls_u_ac:
        str3 = str3 + 'INSERT INTO ACHIEVEMENT (ACHIEVEMENTID, ACHIEVED, TIMESTAMP, "' + filename + ' UNIQUEENTRYID") VALUES (' + str(Counter) +  ", 'False', '13-08-2020', '" + x + "');\n"
        Counter = Counter + 1
    r_ls_1 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_1:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='22-08-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_2 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_2:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='07-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_3 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_3:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_4 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_4:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_5 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_5:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='24-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_6 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_6:
        string = string + "UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_7 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_7:
        string = string +"UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='23-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_8 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_8:
        string = string +"UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='02-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_9 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_9:
        string = string +"UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    r_ls_10 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
    for x in r_ls_10:
        string = string +"UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='13-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_ac.remove(x)
    str1 = str1+string
    str2 = str2+string2

# %%
for file in os_ls_cat:
    filename = str(file).replace('.csv', '').upper()
    string = ""
    string2 = ""
    
    df = pd.read_csv(path3 + '/'+ file)
    ls_u_cat = (df["Unique Entry ID"].tolist())
    for x in ls_u_cat:
        str3 = str3 + 'INSERT INTO ACHIEVEMENT (ACHIEVEMENTID, ACHIEVED, TIMESTAMP, "' + filename + ' UNIQUEENTRYID") VALUES (' + str(Counter) +  ", 'False', '13-08-2020', '" + x + "');\n"
        Counter = Counter + 1
    r_ls_1 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_1:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='22-08-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_2 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_2:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='07-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_3 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_3:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_4 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_4:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_5 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_5:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='24-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_6 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_6:
        string = string + "UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_7 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_7:
        string = string +"UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='23-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_8 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_8:
        string = string +"UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='02-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_9 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_9:
        string = string +"UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    r_ls_10 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
    for x in r_ls_10:
        string = string +"UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='13-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_cat.remove(x)
    str1 = str1+string
    str2 = str2+string2

# %%
for file in os_ls_fur:
    filename = str(file).replace('.csv', '').upper()
    string = ""
    string2 = ""
    
    df = pd.read_csv(path5 + '/'+ file)
    ls_u_fur = (df["Unique Entry ID"].tolist())
    for x in ls_u_fur:
        str3 = str3 + 'INSERT INTO ACHIEVEMENT (ACHIEVEMENTID, ACHIEVED, TIMESTAMP, "' + filename + ' UNIQUEENTRYID") VALUES (' + str(Counter) +  ", 'False', '13-08-2020', '" + x + "');\n"
        Counter = Counter + 1
    r_ls_1 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_1:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='22-08-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_2 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_2:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='07-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_3 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_3:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_4 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_4:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_5 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_5:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='24-09-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_6 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_6:
        string = string + "UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='12-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_7 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_7:
        string = string +"UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='23-10-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_8 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_8:
        string = string +"UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='02-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_9 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_9:
        string = string +"UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='09-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    r_ls_10 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
    for x in r_ls_10:
        string = string +"UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';\n"
        string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='13-11-2020' WHERE '" + filename + " UNIQUEENTRYID'='" + str(x) + "';\n"
        ls_u_fur.remove(x)
    str1 = str1+string
    str2 = str2+string2
# Out:
#   Cell In[363], line 34
#     string2 = string2 + "UPDATE ACHIEVMENT SET Achieved='True',  Timestamp='24-09-2020' WHERE " + '"' + filename + " UNIQUEENTRYID" + '" ' + "='" str(x) + "';\n"
#                                                                                                                                                   ^
# SyntaxError: invalid syntax

# %%
print(str2)
# Out:
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='bK8fXPaAy9f3Nqx9Q';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='9iqmzMJiAeQMBN3pk';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='CA5YASgCBpgL2PSpX';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='chP2wAyDtdSTS3XrF';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='WjbaLp9JbBGYRrb6K';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='fev4af8sNdggceyW9';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='KFNjnL6rqYckLECFB';
# UPDATE ACHIEVMENT SET Achieved=True,  Timestamp='22-08-2020' WHERE 'ACCESSORIES UNIQUEENTRYID'='jvPC7gmEHvxxgmwfA';
# ...

# %%
import random
r_ls_1 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_1:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_2 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_2:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_3 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_3:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_4 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_4:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_5 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_5:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_6 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_6:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_7 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_7:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_8 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_8:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_9 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_9:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
r_ls_10 = random.sample(ls_u_ac, round(len(ls_u_ac)/2))
for x in r_ls_10:
    print("UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_ac.remove(x)
# Out:
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='Hit7pRscB5rzESY7p';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='BswBz2tKc6KjZHai3';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='CPdvmKaZouMuFyZQC';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='RecSgePXKnagDi74R';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='hJKzokWv3YSPCNWBf';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='2WzYimKaSgLB9ukxD';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='z6pi693sEwe2AxrAy';
# UPDATE AnimalCrossing.Wardrobe SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='KiXvv8fvv7CN5sFDx';
# ...

# %%
import random
r_ls_1 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_1:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_2 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_2:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_3 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_3:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_4 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_4:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_5 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_5:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_6 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_6:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_7 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_7:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_8 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_8:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_9 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_9:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
r_ls_10 = random.sample(ls_u_fur, round(len(ls_u_fur)/2))
for x in r_ls_10:
    print("UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_fur.remove(x)
# Out:
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='mbE6PD6F7DR4pjXfS';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='3WLSFAmJsBmyNmeWo';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='HdwrNrMF9ScTMbDcT';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='LYZjssXyPBnNjhT8k';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='2b4iGtMyBGXtCoL7x';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='SyG8yuDJjnxjRRAYJ';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='MGiqeTxYM6pPPFsYw';
# UPDATE AnimalCrossing.Furniture SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='md8ZN6vpy2EdLnXM5';
# ...

# %%
import random
r_ls_1 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_1:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_2 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_2:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-07' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_3 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_3:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_4 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_4:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_5 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_5:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-09-24' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_6 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_6:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-10-12' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_7 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_7:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-10-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_8 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_8:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-02' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_9 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_9:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-09' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
r_ls_10 = random.sample(ls_u_cat, round(len(ls_u_cat)/2))
for x in r_ls_10:
    print("UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-11-23' WHERE UniqueEntryID='" + str(x) + "';")
    ls_u_cat.remove(x)
# Out:
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='2fp9ChfPuPdYefTK3';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='hzwridDJE99rPHLrZ';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='kd5beizyQGeyjeM79';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='TXSteKMHuQ9ZfqPXm';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='qRGGm6MfuP4Aqdk3M';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='poAcys5Mr35ELp5PS';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='M7SHXNEMf78nJD6fE';
# UPDATE AnimalCrossing.Catching SET Achieved=True,  Timestamp='2020-08-22' WHERE UniqueEntryID='APXg8kSzjcmoGGWSP';
# ...

# %%
for file in os_ls_fur:
    print(file)
    df = pd.read_csv(path5 + '/'+ file)
    df["Purchasable"] = ['True' if x == 'For sale' else 'False' for x in df['Catalog']]
    df = df.drop(['Catalog'], axis=1)
    df['Buy'] = df['Buy'].astype('Int64')
    df['Sell'] = round(df['Sell'],0).astype('Int64')
    try:
        df['Kit Cost'] = df['Kit Cost'].astype('Int64')
    except:
        df=df
    try:
        df['Miles Price'] = df['Miles Price'].astype('Int64')
    except:
        df=df
    df['Achieved'] = 'False'
    df['Timestamp'] = '2020-08-13'
        
#     if file == 'miscellaneous.csv':
#         quarter_df = len(df) // 4
#         half_df = len(df) // 2
#         th_quar = quarter_df+half_df
#         first_quart = df.iloc[:quarter_df,]
#         second_quart = df.iloc[quarter_df:half_df,]
#         third_quart = df.iloc[half_df:th_quar,]
#         fourth_quart = df.iloc[th_quar:,]
#         first_quart.to_csv(path5 + '/'+ "first_" + file,index=False)
#         second_quart.to_csv(path5 + '/'+ "second_" +  file,index=False)
#         third_quart.to_csv(path5 + '/'+ "third_" +  file,index=False)
#         fourth_quart.to_csv(path5 + '/'+ "fourth_" +  file,index=False)
    #else:
    df.to_csv(path5 + '/'+ file,index=False)
# Out:
# floors.csv
# housewares.csv
# miscellaneous.csv
# photos.csv
# posters.csv
# rugs.csv
# wall-mounted.csv
# wallpaper.csv

# %%
for file in os_ls_ac:
    df = pd.read_csv(path4 + '/'+ file)
    df["Purchasable"] = ['True' if x == 'For sale' else 'False' for x in df['Catalog']]
    try:
        df["Type"] = df["Primary Shape"]
        df = df.drop(['Catalog', "Primary Shape"], axis=1)
    except:
        df = df.drop(['Catalog'], axis=1)
    try:
        df['Miles Price'] = df['Miles Price'].astype('Int64')
    except:
        df=df
    df['Buy'] = df['Buy'].astype('Int64')
    df['Sell'] = df['Sell'].astype('Int64')
    
#     if file == 'headwear.csv':
#         quarter_df = len(df) // 4
#         half_df = len(df) // 2
#         th_quar = quarter_df+half_df
#         first_quart = df.iloc[:quarter_df,]
#         second_quart = df.iloc[quarter_df:half_df,]
#         third_quart = df.iloc[half_df:th_quar,]
#         fourth_quart = df.iloc[th_quar:,]
#         first_quart.to_csv(path4 + '/'+ "first_" + file,index=False)
#         second_quart.to_csv(path4 + '/'+ "second_" +  file,index=False)
#         third_quart.to_csv(path4 + '/'+ "third_" +  file,index=False)
#         fourth_quart.to_csv(path4 + '/'+ "fourth_" +  file,index=False)
    #else:
    df['Achieved'] = 'False'
    df['Timestamp'] = '2020-08-13'
    df.to_csv(path4 + '/'+ file,index=False)

# %%
for file in os_ls_cat:
    df = pd.read_csv(path3 + '/'+ file)
    df["Critterpedia ID"] = df["#"]
    try:
        df["Weather"] = ["Any except rain" if x == "No" else "Any weather" for x in df["Rain/Snow Catch Up"]]
        df = df.drop(["Rain/Snow Catch Up", "#"], axis=1)
    except:
        df = df.drop(["#"], axis=1)
    #df['Buy'] = df['Buy'].astype('Int64')
    df['Sell'] = df['Sell'].astype('Int64')
    df['Achieved'] = 'False'
    df['Timestamp'] = '2020-08-13'
    df.to_csv(path3 + '/'+ file,index=False)
